# %%
class Node:
    def __init__(self, value):
        self.value=value
        self.next=None

# %%
node=Node(6)
print(node.value)
print(node.next)
# Out:
# 6
# None

# %%
class LinkedList:
    def __init__(self):
        self.head=None

# %%
linked=LinkedList()

print(linked.head)
# Out:
# None

# %%
node=Node(6)

linked=LinkedList()

linked.head=node

print(linked.head.value)
print(linked.head.next)
# Out:
# 6
# None

# %%
class Node:
    def __init__(self, value):
        self.value= value
        self.next=None
        
class LinkedList:
    def __init__(self):
        self.head=None

# %%
node=Node(4)
print(node.value)
print(node.next)
# Out:
# 4
# None

# %%
linked=LinkedList()

linked.head=node

print(linked.head.value)
print(linked.head.next)
# Out:
# 4
# None

# %%
class Node:
    def __init__(self, value):
        self.value=value
        self.next=None

class LinkedList:
    def __init__(self):
        self.head=None

    def print_list(self):
        current=self.head
        while current:
            print( current.value , end= " --> ")
            current= current.next
        print("None")

    def append(self, value):
        new_node=Node(value)

        if not self.head:
            self.head=new_node
            return

        current=self.head
        while current.next:
            current=current.next
        current.next=new_node

# %%
node=Node(8)

li=LinkedList()

li.head=node

print(li.head.value)
print(li.head.next)
# Out:
# 8
# None

# %%
node1=Node(5)
node2=Node(10)
node3=Node(15)
node4=Node(20)

link=LinkedList()

link.head=node1

node1.next=node2
node2.next=node3
node3.next=node4

print(link.head.value)
print(link.head.next.value)
print(link.head.next.next.value)
print(link.head.next.next.next.value)
print(link.head.next.next.next.next)
# Out:
# 5
# 10
# 15
# 20
# None

# %%
node1=Node(5)
node2=Node(10)
node3=Node(15)
node4=Node(20)

link=LinkedList()

link.head=node1

node1.next=node2
node2.next=node3
node3.next=node4

link.print_list()
link.append(25)
link.print_list()
# Out:
# 5 --> 10 --> 15 --> 20 --> None
# 5 --> 10 --> 15 --> 20 --> 25 --> None

# %%
class Node:
    def __init__(self, value):
        self.value=value
        self.next=None

class LinkedList:
    def __init__(self):
        self.head=None

    def print_list(self):
        current=self.head
        while current:
            print(current.value , end= " --> ")
            current= current.next
        print("None")

    def append(self, value):
        new_node=Node(value)

        if not self.head:
            self.head=new_node
            return

        current=self.head
        while current.next:
            current= current.next
        current.next=new_node
    

node1=Node(4)
node2=Node(8)

li=LinkedList()
li.head=node1

node1.next=node2

li.print_list()
li.append(12)
li.print_list()
# Out:
# 4 --> 8 --> None
# 4 --> 8 --> 12 --> None

# %%
class Node:
    def __init__(self, value):
        self.value=value
        self.next=None

class LinkedList:
    def __init__(self):
        self.head=None

    def Print_list(self):
        current=self.head
        while current:
            print(current.value , end= " --> ")
            current= current.next
        print("None")

    def append(self, value):
        new_node=Node(value)

        if not self.head:
            self.head=new_node
            return

        current=self.head
        while current.next:
            current=current.next
        current.next=new_node

    def insert_at_position(self, value, position):
        new_node=Node(value)

        if position == 0:
            new_node.next=selff.head
            self.head=new_node
            return

        current=self.head
        count=0
        while current and count < position -1:
            current = current.next
            count += 1

        if current:
            new_node.next=current.next
            current.next=new_node
        else:
            print("position out of bounds")
            
    def search(self, value):
        current=self.head
        position=0

        while current:
            if current.value==value:
                return position
            else:
                current= current.next
                position +=1
        return -1
        

            

        
        

n=Node(2)
n2=Node(4)
n.next=n2
li=LinkedList()
li.head=n

li.Print_list()
li.append(6)
li.Print_list()

li.insert_at_position(5,2)
li.Print_list()
li.search(10)
# Out:
# 2 --> 4 --> None
# 2 --> 4 --> 6 --> None
# 2 --> 4 --> 5 --> 6 --> None
# -1

# %%
 def insert_at_position(self, value, position):
    new_node = Node(value)

    # Case 1: Insert at the beginning
    if position == 0:
        new_node.next = self.head
        self.head = new_node
        return

    # Case 2: Traverse to the node before the insertion point
    current = self.head
    count = 0
    while current and count < position - 1:
        current = current.next
        count += 1

    # Case 3: Insert in the middle or end
    if current:
        new_node.next = current.next
        current.next = new_node
    else:
        print("Position out of bounds")

# %%
def insert_at_position(self, value, position):
    new_node=Node(value)

    if position == 0:
        new_node.next=self.head
        self.head=new_node
        return

    current=self.head
    count=0
    while current and count < position -1:
        current = current.next
        count += 1

    if current:
        new_node.next=current.next
        current.next=new_node
    else:
        print("position out of bounds")

# %%
def insert_at_position(self, value, position):
    new_node=Node(value)

    if position==0:
        new_node.next=self.head
        self.head= new_node
        return

    current=self.head
    count=0

    while current and count < position - 1:
        current=current.next
        count +=1

    if current:
        new_node.next=current.next
        current.next=new_node
    else:
        print("position out of bounds")

# %%
class Node:
    def __init__(self, value):
        self.value=value
        self.next=None

class LinkedList:
    def __init__(self):
        self.head=None

    def Print_list(self):
        current=self.head
        while current:
            print(current.value, end= " --> ")
            current=current.next
        print("None")
        
    def insert_at_begining(self, value):
        new_node=Node(value)
        new_node.next=self.head
        self.head=new_node
        
        

    def append(self, value):
        new_node=Node(value)

        if not self.head:
            self.head=new_node
            return
            
        current=self.head
        while current.next:
            current=current.next
        current.next=new_node
 

    def insert_at_position(self, value, position):
        new_node=Node(value)

        if position==0:
            new_node.next=self.head
            self.head=new_node
            return

        current=self.head
        count=0
        while current and count < position-1:
            current=current.next
            count +=1

        if current:
            new_node.next=current.next
            current.next=new_node
        else:
            print("position out of bounds")

    def delete_at_position(self, position):
        if not self.head:
            print("it is empty")
            return
            
        if position==0:
            self.head=self.head.next
            return

        current=self.head
        count=0

        while current and count < position - 1:
            current=current.next
            count +=1

        if current and current.next:
            current.next=current.next.next
        else:
            print("invalid positions")
    def delete_by_value(self, value):
        if not self.head:
            print("empty list")
            return

        if self.head.value==value:
            self.head=self.head.next
            return

        current=self.head
        while current.next and current.next.value!=value:
            current=current.next

        if current.next:
            current.next=current.next.next
        else:
            print("value not in list")

    def length(self):
        current=self.head
        counter=0

        while current:
            counter +=1
            current=current.next
        return counter
    




        
        
node1=Node(2)
node2=Node(4)
li=LinkedList()
node1.next=node2
li.head=node1
li.Print_list()
li.append(8)
li.Print_list()
li.insert_at_position(6,2)
li.Print_list()
li.delete_at_position(1)
li.Print_list()
li.append(8)
li.insert_at_begining(0)
li.Print_list()
li.delete_by_value(8)
li.Print_list()
li.length()
# Out:
# 2 --> 4 --> None
# 2 --> 4 --> 8 --> None
# 2 --> 4 --> 6 --> 8 --> None
# 2 --> 6 --> 8 --> None
# 0 --> 2 --> 6 --> 8 --> 8 --> None
# 0 --> 2 --> 6 --> 8 --> None
# 4

# %%
def delete_at_position(self, position):
    if not self.head:
        print("it is empty")
        return

    if position==0:
        self.head=self.head.next
        return

    current=self.head
    count=0

    while current and count < position - 1:
        current= current.next
        count +=1

    if current and current.next:
        current.next=current.next.next
    else:
        print("invalid position")

# %%
def delete_by_value(self, value):
    if not self.head:
        print("List is empty")
        return

    # Case 1: The value is at the head
    if self.head.value == value:
        self.head = self.head.next
        return

    current = self.head

    # Traverse until the node *before* the one we want to delete
    while current.next and current.next.value != value:
        current = current.next

    # Case 2: Found the value
    if current.next:
        current.next = current.next.next
    else:
        # Case 3: Value not found
        print("Value not found in list")

# %%
def insert_at_beginning(self, value):
    new_node = Node(value)
    new_node.next = self.head  # New node points to the old head
    self.head = new_node       # Head now becomes the new node

# %%
def search(self, value):
    current=self.head
    position=0

    while current :
        if current.value==value:
            return position
        else:
            current=current.next
            position +=1
    return -1

# %%
def count(self):
    current=self.head
    c=0
    while current:
        c +=1
        current=current.next

    return c

# %%
def summ(self):
    current=self.head
    summ=0
    while current:
        summ += current.value
        current=current.next
    return summ, count

# %%
def average(self):
    current=self.head
    summ=0
    count=0
    while current:
        summ += current.value
        count +=1
        current=current.next
    average= summ/count
    return summ,  average

# %%
def maxi(self):
    current=self.head
    maxi=current.value
    while current:
        if current.value > maxi:
            maxi=current.value
        current=current.next
    return maxi

# %%
def average(self):
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 li.maxi()
#
# AttributeError: 'LinkedList' object has no attribute 'maxi'
